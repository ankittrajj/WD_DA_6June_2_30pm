# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# line
# bar
# histogram
# pie
# subplot

sales = np.array([23,56,43,89,20])
month = np.array([3,4,5,6,7])
plt.xlabel('SALES')
plt.ylabel("MONTH")
plt.plot(sales,month)

# %%
#wap to make a temp using list and try to viz. the data using
# matplotlib.

# %%
# bar plot---->
sub = ['ML',"AI","python",'SQL']
c1=[34,56,89,23]
c2=[23,45,8,12]
c3= [34,67,23,45]
plt.bar(sub,c1)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(sub,c2,color = ['r','y','g','b'])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(sub,c3)
# Out:
# <BarContainer object of 4 artists>

# %%
# which sub have max students.
# min

# horizontal bars
plt.barh(sub,c3)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(sub,c3,color = 'r')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(sub,c3,align = 'edge')
# Out:
# <BarContainer object of 4 artists>
